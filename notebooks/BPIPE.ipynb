# %%
import blpapi
from blpapi import Event as EventType
from blpapi import AuthOptions, TlsOptions
from datetime import datetime

# %%
# Initialize session options
options = blpapi.SessionOptions()
options.setServerAddress('cloudpoint1.bloomberg.com', 8194, 0)
options.setServerAddress('cloudpoint2.bloomberg.com', 8194, 1)
options.setSessionIdentityOptions(AuthOptions.createWithApp('CHINASILVER:Trading'))

# TLS key files are required for connecting to ZFP endpoint
# They are also generated by BPIPE Admin via EMRS web
options.setTlsOptions(TlsOptions.createFromFiles(r'T:\Intern Folder\External Research\2023 Interns\BPIPE\certificates\65C7B614CC7BF90D81CDE1363A617D85.pk12', '123456', r'T:\Intern Folder\External Research\2023 Interns\BPIPE\certificates\rootCertificate.pk7'))

options.setAutoRestartOnDisconnection(True)
#print(options)

# %%
msgList = []

def onEvent(event, session):
    for msg in event:
        if msg.messageType() in ['MarketDepthUpdates','MarketDataEvents']:
            # retrieve correlation ID from each message
            cid = msg.correlationId().value()
            msg = msg.toPy() # dictionary
            if msg['MKTDEPTH_EVENT_TYPE'] == 'MARKET_BY_ORDER' and msg['EID'] == 14112:
                msg['SUBSCRIPTION_TYPE'] = 'TOP'
            elif msg['MKTDEPTH_EVENT_TYPE'] == 'MARKET_BY_ORDER' and msg['EID'] == 53714:
                msg['SUBSCRIPTION_TYPE'] = 'MBO'
            elif msg['MKTDEPTH_EVENT_TYPE'] == 'MARKET_BY_LEVEL' and msg['EID'] == 14112:
                msg['SUBSCRIPTION_TYPE'] = 'MBL'
            msg['cid'] = cid
            msgList.append(msg)
            
        else:
            print(msg)

# %%
session = blpapi.Session(options, onEvent)
session.start()
# Out:
# SessionConnectionUp = {
#     server = "cloudpoint1.bloomberg.com:8194"
#     serverId = "apidm-ob-946-apicszfb"
#     encryptionStatus = "Encrypted"
#     encryptionCipher = "AES256-GCM-SHA384       TLSv1.2 Kx=RSA      Au=RSA  Enc=AESGCM(256) Mac=AEAD"
#     compressionStatus = "Compressed"
# }
#
# SessionConnectionUp = {
#     server = "cloudpoint2.bloomberg.com:8194"
#     serverId = "apidm-rr-913-apicszfb"
#     encryptionStatus = "Encrypted"
#     encryptionCipher = "AES256-GCM-SHA384       TLSv1.2 Kx=RSA      Au=RSA  Enc=AESGCM(256) Mac=AEAD"
#     compressionStatus = "Compressed"
# }
#
# CID: {[ valueType=AUTOGEN classId=0 value=1 ]}
# RequestId: 7f8c3a05-9999-0a68-0000-34fea8c00500
# ServiceOpened = {
#     serviceName = "//blp/apiauth"
# }
#
# CID: {[ valueType=AUTOGEN classId=0 value=1 ]}
# RequestId: 168ca505-999d-0a68-0000-34fea8c00500
# TokenGenerationSuccess = {
#     token = "-v4;lgHKB5HI7d65C1zuyY9+WjHGQN/G9UUKD0rY12j/jhKl9AQykdqwVBFtF+x0u9HshUyRxdRRWnC0QP8YqannaM879U5BmA+KD3gPA1Kc6Hc=;Pfpx/jbALwgtrEk80jwojTgmoLJjvv/lKZcCY5Z/Q7yLrdkSYDmGw67bociGAhMRoETvVNFORSZre7h/hp8NJfK9y1JGDk9FARmOe92znNo=;"
# }
# True
# CID: {[ valueType=AUTOGEN classId=0 value=1 ]}
# AuthorizationSuccess = {
# }
#
# SessionStarted = {
#     initialEndpoints[] = {
#         initialEndpoints = {
#             address = "cloudpoint1.bloomberg.com:8194"
#         }
#         initialEndpoints = {
#             address = "cloudpoint2.bloomberg.com:8194"
#         }
#     }
# }

# %%
MKTDEPTH_SVC = '//blp/mktdepthdata'
session.openService(MKTDEPTH_SVC)
mktdepth_svc = session.getService(MKTDEPTH_SVC)
# Out:
# CID: {[ valueType=AUTOGEN classId=0 value=8 ]}
# RequestId: 5e8ca905-99b0-0a68-0000-34fea8c00500
# ServiceOpened = {
#     serviceName = "//blp/mktdepthdata"
# }

# %%
ticker = '3738 HK Equity'

subList = blpapi.SubscriptionList()
subList.add(MKTDEPTH_SVC + '/ticker/'+ str(ticker), options='type=TOP', correlationId=blpapi.CorrelationId(ticker+'.type=TOP'))
subList.add(MKTDEPTH_SVC + '/ticker/'+ str(ticker), options='type=MBO', correlationId=blpapi.CorrelationId(ticker+'.type=MBO')) # Need full book 
subList.add(MKTDEPTH_SVC + '/ticker/'+ str(ticker), options='type=MBL', correlationId=blpapi.CorrelationId(ticker+'.type=MBL'))
#subList.add(f'/ticker/{ticker}', fields=['MKTDATA_EVENT_SUBTYPE,EVT_TRADE_TIME_RT,EVT_TRADE_CONDITION_CODE_RT,EVT_TRADE_PRICE_RT,EVT_TRADE_SIZE_RT'], correlationId=blpapi.CorrelationId(ticker+'.type=QR'))

session.subscribe(subList)
# Out:
# CID: {[ valueType=POINTER classId=0 value=0000024F16A576E0 ]}
# RequestId: f68c1405-99b3-0a68-0000-34fea8c00500
# SubscriptionStarted = {
#     exceptions[] = {
#     }
#     streamIds[] = {
#         "1"
#     }
#     receivedFrom = {
#         address = "cloudpoint1.bloomberg.com:8194"
#     }
#     reason = "Subscriber made a subscription"
# }
#
# CID: {[ valueType=POINTER classId=0 value=0000024F16A575A0 ]}
# RequestId: f68c1405-99b3-0a68-0000-34fea8c00500
# SubscriptionStarted = {
#     exceptions[] = {
#     }
#     streamIds[] = {
#         "2"
#     }
#     receivedFrom = {
#         address = "cloudpoint1.bloomberg.com:8194"
#     }
#     reason = "Subscriber made a subscription"
# }
#
# CID: {[ valueType=POINTER classId=0 value=0000024F16A54E40 ]}
# RequestId: f68c1405-99b3-0a68-0000-34fea8c00500
# SubscriptionStarted = {
#     exceptions[] = {
#     }
#     streamIds[] = {
#         "3"
#     }
#     receivedFrom = {
#         address = "cloudpoint1.bloomberg.com:8194"
#     }
#     reason = "Subscriber made a subscription"
# }
#
# CID: {[ valueType=POINTER classId=0 value=0000024F16A54E40 ]}
# RequestId: f58c1d05-99c0-0a68-0000-34fea8c00500
# SubscriptionStreamsActivated = {
#     streams[] = {
#         streams = {
#             id = "3"
#             endpoint = {
#                 address = "cloudpoint1.bloomberg.com:8194"
#             }
#         }
#     }
#     reason = "Subscriber made a subscription"
# }
#
# CID: {[ valueType=POINTER classId=0 value=0000024F16A576E0 ]}
# RequestId: f58c1d05-99c0-0a68-0000-34fea8c00500
# SubscriptionStreamsActivated = {
#     streams[] = {
#         streams = {
#             id = "1"
#             endpoint = {
#                 address = "cloudpoint1.bloomberg.com:8194"
#             }
#         }
#     }
#     reason = "Subscriber made a subscription"
# }
#
# CID: {[ valueType=POINTER classId=0 value=0000024F16A575A0 ]}
# RequestId: f58c1d05-99c0-0a68-0000-34fea8c00500
# SubscriptionStreamsActivated = {
#     streams[] = {
#         streams = {
#             id = "2"
#             endpoint = {
#                 address = "cloudpoint1.bloomberg.com:8194"
#             }
#         }
#     }
#     reason = "Subscriber made a subscription"
# }

# %%
msgList
# Out:
# [{'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'TABLE_INITPAINT',
#   'ID_BB_SEC_NUM_SRC': 730226313488,
#   'FEED_SOURCE': 'HK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_BOOK_TYPE': 'MBL-RBP',
#   'MBL_WINDOW_SIZE': 10,
#   'MD_BOOK_SUBTYPE': 'CLOB',
#   'MD_PRICE_DISPLAY_FORMAT_TYPE_RT': 'DECIMAL',
#   'MD_PRICE_DISPLAY_MIN_NUM_DECIMALS_RT': 2,
#   'MD_PRICE_DISPLAY_MAX_NUM_DECIMALS_RT': 3,
#   'MD_CURRENCY_RT': 'HKD',
#   'MD_QUOTED_CURRENCY_REALTIME': 'HKD',
#   'MD_ROUND_LOT_SIZE_RT': 1000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'TABLE_INITPAINT',
#   'ID_BB_SEC_NUM_SRC': 730226313488,
#   'FEED_SOURCE': 'HK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_BOOK_TYPE': 'TOP-RBP',
#   'MBO_WINDOW_SIZE': 40,
#   'MD_BOOK_SUBTYPE': 'TOPBROKER',
#   'MD_PRICE_DISPLAY_FORMAT_TYPE_RT': 'DECIMAL',
#   'MD_PRICE_DISPLAY_MIN_NUM_DECIMALS_RT': 2,
#   'MD_PRICE_DISPLAY_MAX_NUM_DECIMALS_RT': 3,
#   'MD_CURRENCY_RT': 'HKD',
#   'MD_QUOTED_CURRENCY_REALTIME': 'HKD',
#   'MD_ROUND_LOT_SIZE_RT': 1000,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'TABLE_INITPAINT',
#   'ID_BB_SEC_NUM_SRC': 730226313488,
#   'FEED_SOURCE': 'HK',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MD_BOOK_TYPE': 'MBO-AMD',
#   'MBO_WINDOW_SIZE': 1000,
#   'MBO_SEQNUM_RT': 4,
#   'MD_BOOK_SUBTYPE': 'CLOB',
#   'MD_PRICE_DISPLAY_FORMAT_TYPE_RT': 'DECIMAL',
#   'MD_PRICE_DISPLAY_MIN_NUM_DECIMALS_RT': 2,
#   'MD_PRICE_DISPLAY_MAX_NUM_DECIMALS_RT': 3,
#   'MD_CURRENCY_RT': 'HKD',
#   'MD_QUOTED_CURRENCY_REALTIME': 'HKD',
#   'MD_ROUND_LOT_SIZE_RT': 1000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 3.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 1,
#   'MBL_ASK_SIZE_RT': 1000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 0, 216000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A35060>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 1,
#   'MBO_ASK_RT': 3.0,
#   'MBO_ASK_BROKER_RT': '1166',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A371F0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 2.9600000381469727,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 1,
#   'MBL_ASK_SIZE_RT': 17000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 0, 310000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A373A0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 2,
#   'MBL_ASK_RT': 3.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 1,
#   'MBL_ASK_SIZE_RT': 1000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 0, 310000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A36AD0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 2.9600000381469727,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 2,
#   'MBL_ASK_SIZE_RT': 26000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 0, 315000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A36DD0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 2.9600000381469727,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 3,
#   'MBL_ASK_SIZE_RT': 47000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 0, 317000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A35090>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 2.9600000381469727,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 4,
#   'MBL_ASK_SIZE_RT': 78000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 0, 320000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A36B30>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 1,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1410',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A36A70>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 2,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1419',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A376D0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 3,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1410',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A36980>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 4,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1419',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A375B0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 5,
#   'MBO_ASK_RT': 3.0,
#   'MBO_ASK_BROKER_RT': '1166',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A36B60>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 2.9600000381469727,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 5,
#   'MBL_ASK_SIZE_RT': 87000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 1, 314000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A37C10>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 5,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1410',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 1, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A37D00>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 6,
#   'MBO_ASK_RT': 3.0,
#   'MBO_ASK_BROKER_RT': '1166',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 1, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A377F0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 1, 745000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A37940>),
#   'MBL_BID_POSITION_RT': 1,
#   'MBL_BID_RT': 2.9200000762939453,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 4000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 1, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A37760>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 2.9200000762939453,
#   'MBO_BID_BROKER_RT': '1274',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 1, 885000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A37F70>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 2.8500003814697266,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 5000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 1, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A37430>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8574',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 2, 40000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A36EC0>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 2.8500003814697266,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 2,
#   'MBL_BID_SIZE_RT': 15000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 2, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16727DF0>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8577',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 2, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F167274F0>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 2.75,
#   'MBO_BID_BROKER_RT': ' 775',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F167268C0>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 2.8000001907348633,
#   'MBO_BID_BROKER_RT': '4821',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F167267D0>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 2.75,
#   'MBO_BID_BROKER_RT': ' 775',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, 189000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16727070>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 2.8500003814697266,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 3,
#   'MBL_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16727100>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8155',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16727AF0>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 2.8000001907348633,
#   'MBO_BID_BROKER_RT': '4821',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F167267A0>),
#   'MBO_BID_POSITION_RT': 6,
#   'MBO_BID_RT': 2.75,
#   'MBO_BID_BROKER_RT': ' 775',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, 426000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16726B00>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 2.859999656677246,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 7000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, 426000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F1676C4F0>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 2.8500003814697266,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 3,
#   'MBL_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C0A0>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 2.859999656677246,
#   'MBO_BID_BROKER_RT': '4821',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C160>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8574',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C220>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8577',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C2E0>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8155',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C3A0>),
#   'MBO_BID_POSITION_RT': 6,
#   'MBO_BID_RT': 2.8000001907348633,
#   'MBO_BID_BROKER_RT': '4821',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C460>),
#   'MBO_BID_POSITION_RT': 7,
#   'MBO_BID_RT': 2.75,
#   'MBO_BID_BROKER_RT': ' 775',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 4, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C520>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 2.859999656677246,
#   'MBO_BID_BROKER_RT': '4821',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 4, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C5E0>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8574',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 4, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C6A0>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8577',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 4, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C760>),
#   'MBO_BID_POSITION_RT': 6,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8155',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 4, 173000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C820>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 2.859999656677246,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 2,
#   'MBL_BID_SIZE_RT': 11000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 4, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C8E0>),
#   'MBO_BID_POSITION_RT': 7,
#   'MBO_BID_RT': 2.8000001907348633,
#   'MBO_BID_BROKER_RT': '4821',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 4, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9C9A0>),
#   'MBO_BID_POSITION_RT': 8,
#   'MBO_BID_RT': 2.75,
#   'MBO_BID_BROKER_RT': ' 775',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 2.9600000381469727,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 4,
#   'MBL_ASK_SIZE_RT': 70000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 7, 952000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9CA60>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 1,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1419',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 7, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9CB20>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 2,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1410',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 7, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9CBE0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 3,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1419',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 7, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9CCA0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 4,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1410',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 7, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9CD60>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 5,
#   'MBO_ASK_RT': 3.0,
#   'MBO_ASK_BROKER_RT': '1166',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 7, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9CE20>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_ASK_POSITION_RT': 6,
#   'MBO_ASK_RT': 0.0,
#   'MBO_ASK_BROKER_RT': '',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 7, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9CEE0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 2.9600000381469727,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 3,
#   'MBL_ASK_SIZE_RT': 61000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 11, 477000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9CFA0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 1,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1410',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 11, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D060>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 2,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1419',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 11, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D120>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 3,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1410',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 11, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D1E0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 4,
#   'MBO_ASK_RT': 3.0,
#   'MBO_ASK_BROKER_RT': '1166',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 11, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D2A0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_ASK_POSITION_RT': 5,
#   'MBO_ASK_RT': 0.0,
#   'MBO_ASK_BROKER_RT': '',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 11, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D360>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 2,
#   'MBL_ASK_RT': 3.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 2,
#   'MBL_ASK_SIZE_RT': 5000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 12, 168000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D420>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 5,
#   'MBO_ASK_RT': 3.0,
#   'MBO_ASK_BROKER_RT': '4665',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 12, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D4E0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 13, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D5A0>),
#   'MBO_BID_POSITION_RT': 7,
#   'MBO_BID_RT': 2.8199996948242188,
#   'MBO_BID_BROKER_RT': '6835',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 13, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D660>),
#   'MBO_BID_POSITION_RT': 8,
#   'MBO_BID_RT': 2.8000001907348633,
#   'MBO_BID_BROKER_RT': '4821',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 13, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D720>),
#   'MBO_BID_POSITION_RT': 9,
#   'MBO_BID_RT': 2.75,
#   'MBO_BID_BROKER_RT': ' 775',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 2.9600000381469727,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 2,
#   'MBL_ASK_SIZE_RT': 40000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, 475000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D7E0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 1,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1419',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D8A0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 2,
#   'MBO_ASK_RT': 2.9600000381469727,
#   'MBO_ASK_BROKER_RT': '1410',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9D960>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 3,
#   'MBO_ASK_RT': 3.0,
#   'MBO_ASK_BROKER_RT': '1166',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9DA20>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 4,
#   'MBO_ASK_RT': 3.0,
#   'MBO_ASK_BROKER_RT': '4665',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9DAE0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_ASK_POSITION_RT': 5,
#   'MBO_ASK_RT': 0.0,
#   'MBO_ASK_BROKER_RT': '',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9DBA0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9DC60>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 2.859999656677246,
#   'MBO_BID_BROKER_RT': '5078',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9DD20>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8574',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9DDE0>),
#   'MBO_BID_POSITION_RT': 6,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8577',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9DEA0>),
#   'MBO_BID_POSITION_RT': 7,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8155',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9DF60>),
#   'MBO_BID_POSITION_RT': 8,
#   'MBO_BID_RT': 2.8199996948242188,
#   'MBO_BID_BROKER_RT': '6835',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E020>),
#   'MBO_BID_POSITION_RT': 9,
#   'MBO_BID_RT': 2.8000001907348633,
#   'MBO_BID_BROKER_RT': '4821',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E0E0>),
#   'MBO_BID_POSITION_RT': 10,
#   'MBO_BID_RT': 2.75,
#   'MBO_BID_BROKER_RT': ' 775',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 14, 628000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E1A0>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 2.859999656677246,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 3,
#   'MBL_BID_SIZE_RT': 21000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E260>),
#   'MBL_BID_POSITION_RT': 1,
#   'MBL_BID_RT': 3.1000003814697266,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 80000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E320>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 2.9200000762939453,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 4000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E3E0>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 2.859999656677246,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 3,
#   'MBL_BID_SIZE_RT': 21000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E4A0>),
#   'MBL_BID_POSITION_RT': 4,
#   'MBL_BID_RT': 2.8500003814697266,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 3,
#   'MBL_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 3.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 2,
#   'MBL_ASK_SIZE_RT': 5000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E560>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 2,
#   'MBL_ASK_RT': 0.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 0,
#   'MBL_ASK_SIZE_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E620>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 0.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 0,
#   'MBL_ASK_SIZE_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E6E0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 3.1000003814697266,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 4,
#   'MBL_ASK_SIZE_RT': 45000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E7A0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E860>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 2.859999656677246,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 3,
#   'MBL_BID_SIZE_RT': 21000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E920>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 2.8500003814697266,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 3,
#   'MBL_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9E9E0>),
#   'MBL_BID_POSITION_RT': 4,
#   'MBL_BID_RT': 0.0,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 0,
#   'MBL_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9EAA0>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 2.8500003814697266,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 3,
#   'MBL_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9EB60>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.0,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 0,
#   'MBL_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 143000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9EC20>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 0.0,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 0,
#   'MBL_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 1,
#   'MBO_ASK_RT': 3.1000003814697266,
#   'MBO_ASK_BROKER_RT': '1419',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9ECE0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 2,
#   'MBO_ASK_RT': 3.1000003814697266,
#   'MBO_ASK_BROKER_RT': '1410',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9EDA0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 3,
#   'MBO_ASK_RT': 3.1000003814697266,
#   'MBO_ASK_BROKER_RT': '1166',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9EE60>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 4,
#   'MBO_ASK_RT': 3.1000003814697266,
#   'MBO_ASK_BROKER_RT': '4665',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9EF20>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9EFE0>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 3.1000003814697266,
#   'MBO_BID_BROKER_RT': '1172',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9F0A0>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 2.9200000762939453,
#   'MBO_BID_BROKER_RT': '1274',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9F160>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.0,
#   'MBO_BID_BROKER_RT': '',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9F220>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 0.0,
#   'MBO_BID_BROKER_RT': '',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9F2E0>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 0.0,
#   'MBO_BID_BROKER_RT': '',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9F3A0>),
#   'MBO_BID_POSITION_RT': 6,
#   'MBO_BID_RT': 0.0,
#   'MBO_BID_BROKER_RT': '',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9F460>),
#   'MBO_BID_POSITION_RT': 7,
#   'MBO_BID_RT': 0.0,
#   'MBO_BID_BROKER_RT': '',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9F520>),
#   'MBO_BID_POSITION_RT': 8,
#   'MBO_BID_RT': 0.0,
#   'MBO_BID_BROKER_RT': '',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9F5E0>),
#   'MBO_BID_POSITION_RT': 9,
#   'MBO_BID_RT': 0.0,
#   'MBO_BID_BROKER_RT': '',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9F6A0>),
#   'MBO_BID_POSITION_RT': 10,
#   'MBO_BID_RT': 0.0,
#   'MBO_BID_BROKER_RT': '',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 3.1000003814697266,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 5,
#   'MBL_ASK_SIZE_RT': 52000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, 153000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9F760>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 1,
#   'MBO_ASK_RT': 3.1000003814697266,
#   'MBO_ASK_BROKER_RT': '3275',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 0, 16, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16A9F820>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
# ...
#   'MBO_BID_RT': 2.859999656677246,
#   'MBO_BID_BROKER_RT': '4821',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B307F0>),
#   'MBO_BID_POSITION_RT': 10,
#   'MBO_BID_RT': 2.859999656677246,
#   'MBO_BID_BROKER_RT': '5078',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B308B0>),
#   'MBO_BID_POSITION_RT': 11,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8574',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B30970>),
#   'MBO_BID_POSITION_RT': 12,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8577',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B30A30>),
#   'MBO_BID_POSITION_RT': 13,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '5998',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B30AF0>),
#   'MBO_BID_POSITION_RT': 14,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8464',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B30BB0>),
#   'MBO_BID_POSITION_RT': 15,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '9053',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B30C70>),
#   'MBO_BID_POSITION_RT': 16,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8306',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B30D30>),
#   'MBO_BID_POSITION_RT': 17,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8302',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B30DF0>),
#   'MBO_BID_POSITION_RT': 18,
#   'MBO_BID_RT': 2.8400001525878906,
#   'MBO_BID_BROKER_RT': '8597',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B30EB0>),
#   'MBO_BID_POSITION_RT': 19,
#   'MBO_BID_RT': 2.8400001525878906,
#   'MBO_BID_BROKER_RT': '5999',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B30F70>),
#   'MBO_BID_POSITION_RT': 20,
#   'MBO_BID_RT': 2.8299999237060547,
#   'MBO_BID_BROKER_RT': '8303',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31030>),
#   'MBO_BID_POSITION_RT': 21,
#   'MBO_BID_RT': 2.8299999237060547,
#   'MBO_BID_BROKER_RT': '8467',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B310F0>),
#   'MBO_BID_POSITION_RT': 22,
#   'MBO_BID_RT': 2.8199996948242188,
#   'MBO_BID_BROKER_RT': '6835',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B311B0>),
#   'MBO_BID_POSITION_RT': 23,
#   'MBO_BID_RT': 2.810000419616699,
#   'MBO_BID_BROKER_RT': '2398',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31270>),
#   'MBO_BID_POSITION_RT': 24,
#   'MBO_BID_RT': 2.810000419616699,
#   'MBO_BID_BROKER_RT': '4821',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 12, 48, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31330>),
#   'MBO_BID_POSITION_RT': 25,
#   'MBO_BID_RT': 0.0,
#   'MBO_BID_BROKER_RT': '',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, 493000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B313F0>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 2.880000114440918,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 3000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, 493000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B314B0>),
#   'MBL_BID_POSITION_RT': 4,
#   'MBL_BID_RT': 2.859999656677246,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 3,
#   'MBL_BID_SIZE_RT': 21000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, 493000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31570>),
#   'MBL_BID_POSITION_RT': 5,
#   'MBL_BID_RT': 2.8500003814697266,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 7,
#   'MBL_BID_SIZE_RT': 230000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, 493000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31630>),
#   'MBL_BID_POSITION_RT': 6,
#   'MBL_BID_RT': 2.8400001525878906,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 2,
#   'MBL_BID_SIZE_RT': 52000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, 493000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B316F0>),
#   'MBL_BID_POSITION_RT': 7,
#   'MBL_BID_RT': 2.8299999237060547,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 2,
#   'MBL_BID_SIZE_RT': 15000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B317B0>),
#   'MBO_BID_POSITION_RT': 8,
#   'MBO_BID_RT': 2.880000114440918,
#   'MBO_BID_BROKER_RT': '4821',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31870>),
#   'MBO_BID_POSITION_RT': 10,
#   'MBO_BID_RT': 2.859999656677246,
#   'MBO_BID_BROKER_RT': '4821',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31930>),
#   'MBO_BID_POSITION_RT': 11,
#   'MBO_BID_RT': 2.859999656677246,
#   'MBO_BID_BROKER_RT': '5078',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B319F0>),
#   'MBO_BID_POSITION_RT': 12,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8574',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31AB0>),
#   'MBO_BID_POSITION_RT': 13,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8577',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31B70>),
#   'MBO_BID_POSITION_RT': 14,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '5998',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31C30>),
#   'MBO_BID_POSITION_RT': 15,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8464',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31CF0>),
#   'MBO_BID_POSITION_RT': 16,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '9053',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31DB0>),
#   'MBO_BID_POSITION_RT': 17,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8306',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31E70>),
#   'MBO_BID_POSITION_RT': 18,
#   'MBO_BID_RT': 2.8500003814697266,
#   'MBO_BID_BROKER_RT': '8302',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31F30>),
#   'MBO_BID_POSITION_RT': 19,
#   'MBO_BID_RT': 2.8400001525878906,
#   'MBO_BID_BROKER_RT': '8597',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B31FF0>),
#   'MBO_BID_POSITION_RT': 20,
#   'MBO_BID_RT': 2.8400001525878906,
#   'MBO_BID_BROKER_RT': '5999',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B320B0>),
#   'MBO_BID_POSITION_RT': 21,
#   'MBO_BID_RT': 2.8299999237060547,
#   'MBO_BID_BROKER_RT': '8303',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B32170>),
#   'MBO_BID_POSITION_RT': 22,
#   'MBO_BID_RT': 2.8299999237060547,
#   'MBO_BID_BROKER_RT': '8467',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 16, 1, 13, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024F16B32230>),
#   'MBO_BID_POSITION_RT': 23,
#   'MBO_BID_RT': 2.8199996948242188,
#   'MBO_BID_BROKER_RT': '6835',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  ...]

# %%
print(len(msgList))
# Out:
# 2793

# %%
msg = msgList[2] # if 'MKTDEPTH_EVENT_TYPE' == 'MARKET_BY_ORDER'; 'MKTDEPTH_EVENT_SUBTYPE' == 'TABLE_INITPAINT'
for x in msg['MBO_TABLE_ASK']:
    print(f"Ask {x['MBO_ASK_POSITION_RT']}: Broker {x['MBO_ASK_BROKER_RT']} offering at {x['MBO_ASK_RT']} on {x['MBO_TIME_RT'].astimezone()}")
    
for x in msg['MBO_TABLE_BID']:
    print(f"Bid {x['MBO_BID_POSITION_RT']}: Broker {x['MBO_BID_BROKER_RT']} bidding at {x['MBO_BID_RT']} on {x['MBO_TIME_RT'].astimezone()}")
# Out:
# Ask 1: Broker 1836 offering at 2.40000057220459 on 2023-06-12 10:16:58+08:00
# Ask 2: Broker 5998 offering at 2.40000057220459 on 2023-06-12 10:16:58+08:00
# Ask 3: Broker 3436 offering at 2.40000057220459 on 2023-06-12 10:19:12+08:00
# Ask 4: Broker 5346 offering at 2.40000057220459 on 2023-06-12 10:19:39+08:00
# Ask 5: Broker 5999 offering at 2.4099998474121094 on 2023-06-12 10:22:15+08:00
# Ask 6: Broker 6387 offering at 2.4099998474121094 on 2023-06-12 10:22:15+08:00
# Ask 7: Broker 5998 offering at 2.4099998474121094 on 2023-06-12 10:22:15+08:00
# Ask 8: Broker 6387 offering at 2.4099998474121094 on 2023-06-12 10:22:15+08:00
# Ask 9: Broker 6387 offering at 2.4099998474121094 on 2023-06-12 10:18:22+08:00
# Ask 10: Broker 6387 offering at 2.4099998474121094 on 2023-06-12 10:19:39+08:00
# Ask 11: Broker 6387 offering at 2.4099998474121094 on 2023-06-12 10:20:14+08:00
# Ask 12: Broker 6387 offering at 2.4099998474121094 on 2023-06-12 10:20:45+08:00
# Ask 13: Broker 5999 offering at 2.4099998474121094 on 2023-06-12 10:23:22+08:00
# Ask 14: Broker 5999 offering at 2.4200000762939453 on 2023-06-12 10:27:18+08:00
# Ask 15: Broker 8550 offering at 2.4300003051757812 on 2023-06-12 10:27:18+08:00
# Ask 16: Broker 4376 offering at 2.4300003051757812 on 2023-06-12 10:27:18+08:00
# Ask 17: Broker 5999 offering at 2.440000534057617 on 2023-06-12 10:27:18+08:00
# Ask 18: Broker 7368 offering at 2.440000534057617 on 2023-06-12 10:27:18+08:00
# Ask 19: Broker 7368 offering at 2.440000534057617 on 2023-06-12 10:20:14+08:00
# Ask 20: Broker 7368 offering at 2.440000534057617 on 2023-06-12 10:20:45+08:00
# Ask 21: Broker 7368 offering at 2.440000534057617 on 2023-06-12 10:23:22+08:00
# Ask 22: Broker 4376 offering at 2.440000534057617 on 2023-06-12 10:27:18+08:00
# Ask 23: Broker 2079 offering at 2.440000534057617 on 2023-06-12 10:27:18+08:00
# Ask 24: Broker 4450 offering at 2.4499998092651367 on 2023-06-12 10:27:18+08:00
# Ask 25: Broker 6998 offering at 2.4499998092651367 on 2023-06-12 10:27:18+08:00
# Ask 26: Broker 2077 offering at 2.4499998092651367 on 2023-06-12 10:27:18+08:00
# Ask 27: Broker 4376 offering at 2.4499998092651367 on 2023-06-12 10:27:18+08:00
# Ask 28: Broker  147 offering at 2.4600000381469727 on 2023-06-12 10:27:18+08:00
# Ask 29: Broker 2077 offering at 2.4600000381469727 on 2023-06-12 10:27:18+08:00
# Ask 30: Broker 4838 offering at 2.4800004959106445 on 2023-06-12 10:27:18+08:00
# Ask 31: Broker 2976 offering at 2.4800004959106445 on 2023-06-12 10:27:18+08:00
# Bid 1: Broker 2421 bidding at 2.380000114440918 on 2023-06-12 10:18:22+08:00
# Bid 2: Broker 5999 bidding at 2.380000114440918 on 2023-06-12 10:18:22+08:00
# Bid 3: Broker 5998 bidding at 2.380000114440918 on 2023-06-12 10:18:22+08:00
# Bid 4: Broker 6387 bidding at 2.380000114440918 on 2023-06-12 10:18:22+08:00
# Bid 5: Broker 2079 bidding at 2.380000114440918 on 2023-06-12 10:20:06+08:00
# Bid 6: Broker 5337 bidding at 2.380000114440918 on 2023-06-12 10:20:06+08:00
# Bid 7: Broker 8049 bidding at 2.380000114440918 on 2023-06-12 10:20:06+08:00
# Bid 8: Broker 3265 bidding at 2.380000114440918 on 2023-06-12 10:20:14+08:00
# Bid 9: Broker 9068 bidding at 2.380000114440918 on 2023-06-12 10:26:16+08:00
# Bid 10: Broker 5347 bidding at 2.369999885559082 on 2023-06-12 10:26:16+08:00
# Bid 11: Broker 3508 bidding at 2.369999885559082 on 2023-06-12 10:26:16+08:00
# Bid 12: Broker 2427 bidding at 2.369999885559082 on 2023-06-12 10:26:16+08:00
# Bid 13: Broker 2421 bidding at 2.369999885559082 on 2023-06-12 10:26:16+08:00
# Bid 14: Broker 2045 bidding at 2.369999885559082 on 2023-06-12 10:26:16+08:00
# Bid 15: Broker 6387 bidding at 2.369999885559082 on 2023-06-12 10:26:16+08:00
# Bid 16: Broker 5999 bidding at 2.369999885559082 on 2023-06-12 10:26:16+08:00
# Bid 17: Broker 5999 bidding at 2.369999885559082 on 2023-06-12 10:21:12+08:00
# Bid 18: Broker 2077 bidding at 2.369999885559082 on 2023-06-12 10:26:16+08:00
# Bid 19: Broker 6998 bidding at 2.369999885559082 on 2023-06-12 10:26:16+08:00
# Bid 20: Broker 8567 bidding at 2.369999885559082 on 2023-06-12 10:26:16+08:00
# Bid 21: Broker 8466 bidding at 2.369999885559082 on 2023-06-12 10:26:16+08:00
# Bid 22: Broker 8550 bidding at 2.359999656677246 on 2023-06-12 10:24:45+08:00
# Bid 23: Broker 6999 bidding at 2.359999656677246 on 2023-06-12 10:24:45+08:00
# Bid 24: Broker 2079 bidding at 2.359999656677246 on 2023-06-12 10:24:45+08:00
# Bid 25: Broker 8760 bidding at 2.359999656677246 on 2023-06-12 10:24:45+08:00
# Bid 26: Broker 1388 bidding at 2.3500003814697266 on 2023-06-12 10:24:45+08:00
# Bid 27: Broker 5999 bidding at 2.3500003814697266 on 2023-06-12 10:24:45+08:00
# Bid 28: Broker 1172 bidding at 2.3500003814697266 on 2023-06-12 10:24:45+08:00
# Bid 29: Broker 5999 bidding at 2.3500003814697266 on 2023-06-12 10:24:45+08:00
# Bid 30: Broker 5998 bidding at 2.3500003814697266 on 2023-06-12 10:24:45+08:00
# Bid 31: Broker 5999 bidding at 2.3500003814697266 on 2023-06-12 10:24:45+08:00
# Bid 32: Broker 8577 bidding at 2.3500003814697266 on 2023-06-12 10:24:45+08:00
# Bid 33: Broker 8306 bidding at 2.3500003814697266 on 2023-06-12 10:24:45+08:00
# Bid 34: Broker 1836 bidding at 2.3400001525878906 on 2023-06-12 10:24:45+08:00
# Bid 35: Broker 4376 bidding at 2.3400001525878906 on 2023-06-12 10:24:45+08:00
# Bid 36: Broker 4450 bidding at 2.3400001525878906 on 2023-06-12 10:24:45+08:00

# %%
msgList[1]
# Out:
# {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#  'MKTDEPTH_EVENT_SUBTYPE': 'TABLE_INITPAINT',
#  'ID_BB_SEC_NUM_SRC': 730145003912,
#  'FEED_SOURCE': 'HK',
#  'EID': 14112,
#  'MD_TABLE_CMD_RT': 'REPLACE',
#  'MD_BOOK_TYPE': 'MBL-RBP',
#  'MBL_WINDOW_SIZE': 10,
#  'MD_BOOK_SUBTYPE': 'CLOB',
#  'MD_PRICE_DISPLAY_FORMAT_TYPE_RT': 'DECIMAL',
#  'MD_PRICE_DISPLAY_MIN_NUM_DECIMALS_RT': 2,
#  'MD_PRICE_DISPLAY_MAX_NUM_DECIMALS_RT': 3,
#  'MD_CURRENCY_RT': 'HKD',
#  'MD_QUOTED_CURRENCY_REALTIME': 'HKD',
#  'MD_ROUND_LOT_SIZE_RT': 2000,
#  'MBL_TABLE_ASK': [{'MBL_ASK_POSITION_RT': 1,
#    'MBL_ASK_RT': 0.9200000166893005,
#    'MBL_ASK_COND_CODE_RT': '',
#    'MBL_ASK_NUM_ORDERS_RT': 1,
#    'MBL_ASK_SIZE_RT': 12000,
#    'MBL_TIME_RT': datetime.datetime(2023, 6, 9, 1, 30, 18, 21000, tzinfo=<blpapi.datetime.FixedOffset object at 0x000001E4ABAC6CB0>),
#    'MD_TABLE_CMD_RT': 'REPLACE'},
#   {'MBL_ASK_POSITION_RT': 2,
#    'MBL_ASK_RT': 1.0,
#    'MBL_ASK_COND_CODE_RT': '',
#    'MBL_ASK_NUM_ORDERS_RT': 1,
#    'MBL_ASK_SIZE_RT': 10000,
#    'MBL_TIME_RT': datetime.datetime(2023, 6, 9, 1, 30, 18, 21000, tzinfo=<blpapi.datetime.FixedOffset object at 0x000001E4ABAC6B30>),
#    'MD_TABLE_CMD_RT': 'REPLACE'}],
#  'MBL_TABLE_BID': [{'MBL_BID_POSITION_RT': 1,
#    'MBL_BID_RT': 0.8700000047683716,
#    'MBL_BID_COND_CODE_RT': '',
#    'MBL_BID_NUM_ORDERS_RT': 2,
#    'MBL_TIME_RT': datetime.datetime(2023, 6, 9, 1, 32, 50, 957000, tzinfo=<blpapi.datetime.FixedOffset object at 0x000001E4ABAC7100>),
#    'MBL_BID_SIZE_RT': 4000,
#    'MD_TABLE_CMD_RT': 'REPLACE'},
#   {'MBL_BID_POSITION_RT': 2,
#    'MBL_BID_RT': 0.8299999833106995,
#    'MBL_BID_COND_CODE_RT': '',
#    'MBL_BID_NUM_ORDERS_RT': 1,
#    'MBL_TIME_RT': datetime.datetime(2023, 6, 9, 1, 32, 59, 596000, tzinfo=<blpapi.datetime.FixedOffset object at 0x000001E4ABAC7F40>),
#    'MBL_BID_SIZE_RT': 6000,
#    'MD_TABLE_CMD_RT': 'REPLACE'},
#   {'MBL_BID_POSITION_RT': 3,
#    'MBL_BID_RT': 0.8199999928474426,
#    'MBL_BID_COND_CODE_RT': '',
#    'MBL_BID_NUM_ORDERS_RT': 1,
#    'MBL_TIME_RT': datetime.datetime(2023, 6, 9, 1, 32, 59, 596000, tzinfo=<blpapi.datetime.FixedOffset object at 0x000001E4ABAC72B0>),
#    'MBL_BID_SIZE_RT': 2000,
#    'MD_TABLE_CMD_RT': 'REPLACE'}]}

# %%
datetime.microsecond

# %%
x['MBO_TIME_RT']
# Out:
# datetime.datetime(2023, 6, 9, 1, 32, 59, tzinfo=<blpapi.datetime.FixedOffset object at 0x000001E4ABAC7520>)

# %%
# DEMO only: cancel here once enough messages are received
session.cancel(cid)
# Out:
# CID: {[ valueType=POINTER classId=0 value=00000202E734CFD0 ]}
# SubscriptionTerminated = {
#     reason = {
#         source = "SubscriptionManager"
#         category = "CANCELLED"
#         errorCode = 0
#         description = "Subscription cancelled"
#     }
# }

# %%
session.stop()
# Out:
# True

# %%
import pickle

with open('3738_HK_msgList_0616.pickle','wb') as f:
    pickle.dump(msgList, f)

#msgList

# %%
import pickle

with open('3738_msgList.pickle','rb') as f:
    msgList = pickle.load(f)

# %%
msgList
# Out:
# [{'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'TABLE_INITPAINT',
#   'ID_BB_SEC_NUM_SRC': 730145003912,
#   'FEED_SOURCE': 'HK',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MD_BOOK_TYPE': 'MBO-AMD',
#   'MBO_WINDOW_SIZE': 1000,
#   'MBO_SEQNUM_RT': 7,
#   'MD_BOOK_SUBTYPE': 'CLOB',
#   'MD_PRICE_DISPLAY_FORMAT_TYPE_RT': 'DECIMAL',
#   'MD_PRICE_DISPLAY_MIN_NUM_DECIMALS_RT': 2,
#   'MD_PRICE_DISPLAY_MAX_NUM_DECIMALS_RT': 3,
#   'MD_CURRENCY_RT': 'HKD',
#   'MD_QUOTED_CURRENCY_REALTIME': 'HKD',
#   'MD_ROUND_LOT_SIZE_RT': 2000,
#   'MBO_TABLE_ASK': [{'MBO_ASK_POSITION_RT': 1,
#     'MBO_ASK_RT': 0.8999999761581421,
#     'MBO_ASK_COND_CODE_RT': '',
#     'MBO_ORDER_ID_RT': '9121025',
#     'MBO_ASK_SIZE_RT': 2000,
#     'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 20, 20, 635000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58307A30>),
#     'MD_TABLE_CMD_RT': 'ADD'},
#    {'MBO_ASK_POSITION_RT': 2,
#     'MBO_ASK_RT': 1.0,
#     'MBO_ASK_COND_CODE_RT': '',
#     'MBO_ORDER_ID_RT': '2868225',
#     'MBO_ASK_SIZE_RT': 10000,
#     'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 20, 20, 635000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58307130>),
#     'MD_TABLE_CMD_RT': 'ADD'}],
#   'MBO_TABLE_BID': [{'MBO_BID_POSITION_RT': 1,
#     'MBO_BID_RT': 0.8100000023841858,
#     'MBO_BID_COND_CODE_RT': '',
#     'MBO_ORDER_ID_RT': '5296129',
#     'MBO_BID_SIZE_RT': 20000,
#     'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 20, 20, 635000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58307370>),
#     'MD_TABLE_CMD_RT': 'ADD'}],
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'TABLE_INITPAINT',
#   'ID_BB_SEC_NUM_SRC': 730145003912,
#   'FEED_SOURCE': 'HK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_BOOK_TYPE': 'MBL-RBP',
#   'MBL_WINDOW_SIZE': 10,
#   'MD_BOOK_SUBTYPE': 'CLOB',
#   'MD_PRICE_DISPLAY_FORMAT_TYPE_RT': 'DECIMAL',
#   'MD_PRICE_DISPLAY_MIN_NUM_DECIMALS_RT': 2,
#   'MD_PRICE_DISPLAY_MAX_NUM_DECIMALS_RT': 3,
#   'MD_CURRENCY_RT': 'HKD',
#   'MD_QUOTED_CURRENCY_REALTIME': 'HKD',
#   'MD_ROUND_LOT_SIZE_RT': 2000,
#   'MBL_TABLE_ASK': [{'MBL_ASK_POSITION_RT': 1,
#     'MBL_ASK_RT': 0.8999999761581421,
#     'MBL_ASK_COND_CODE_RT': '',
#     'MBL_ASK_NUM_ORDERS_RT': 1,
#     'MBL_ASK_SIZE_RT': 2000,
#     'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 5, 27, 481000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58306860>),
#     'MD_TABLE_CMD_RT': 'REPLACE'}],
#   'MBL_TABLE_BID': [{'MBL_BID_POSITION_RT': 1,
#     'MBL_BID_RT': 0.8100000023841858,
#     'MBL_BID_COND_CODE_RT': '',
#     'MBL_BID_NUM_ORDERS_RT': 1,
#     'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 0, 46, 25000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58306D70>),
#     'MBL_BID_SIZE_RT': 20000,
#     'MD_TABLE_CMD_RT': 'REPLACE'}],
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'TABLE_INITPAINT',
#   'ID_BB_SEC_NUM_SRC': 730145003912,
#   'FEED_SOURCE': 'HK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_BOOK_TYPE': 'TOP-RBP',
#   'MBO_WINDOW_SIZE': 40,
#   'MD_BOOK_SUBTYPE': 'TOPBROKER',
#   'MD_PRICE_DISPLAY_FORMAT_TYPE_RT': 'DECIMAL',
#   'MD_PRICE_DISPLAY_MIN_NUM_DECIMALS_RT': 2,
#   'MD_PRICE_DISPLAY_MAX_NUM_DECIMALS_RT': 3,
#   'MD_CURRENCY_RT': 'HKD',
#   'MD_QUOTED_CURRENCY_REALTIME': 'HKD',
#   'MD_ROUND_LOT_SIZE_RT': 2000,
#   'MBO_TABLE_ASK': [{'MBO_ASK_POSITION_RT': 1,
#     'MBO_ASK_RT': 0.8999999761581421,
#     'MBO_ASK_BROKER_RT': '8461',
#     'MBO_ASK_COND_CODE_RT': '',
#     'MBO_ASK_SIZE_RT': 0,
#     'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 5, 27, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58601060>),
#     'MD_TABLE_CMD_RT': 'REPLACE'},
#    {'MBO_ASK_POSITION_RT': 2,
#     'MBO_ASK_RT': 1.0,
#     'MBO_ASK_BROKER_RT': ' 298',
#     'MBO_ASK_COND_CODE_RT': '',
#     'MBO_ASK_SIZE_RT': 0,
#     'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 5, 27, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586033D0>),
#     'MD_TABLE_CMD_RT': 'REPLACE'}],
#   'MBO_TABLE_BID': [{'MBO_BID_POSITION_RT': 1,
#     'MBO_BID_RT': 0.8100000023841858,
#     'MBO_BID_BROKER_RT': '1836',
#     'MBO_BID_COND_CODE_RT': '',
#     'MBO_BID_SIZE_RT': 0,
#     'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 0, 46, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58603010>),
#     'MD_TABLE_CMD_RT': 'REPLACE'}],
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 8,
#   'MBO_ORDER_ID_RT': '15476993',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 30, 3, 294000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586014B0>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 0.8799999952316284,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 30, 3, 294000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586029B0>),
#   'MBL_BID_POSITION_RT': 1,
#   'MBL_BID_RT': 0.8799999952316284,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 30, 3, 294000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58603130>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 30, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58603400>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 0.8799999952316284,
#   'MBO_BID_BROKER_RT': '8578',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 30, 3, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58603910>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 0.8100000023841858,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 9,
#   'MBO_ORDER_ID_RT': '31445761',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 30, 32, 748000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58603EE0>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 10000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 30, 32, 748000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586036A0>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 0.8199999928474426,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 10000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 30, 32, 748000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58603F70>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 30, 32, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58603F10>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_BROKER_RT': '7368',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 30, 32, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58602860>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.8100000023841858,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 10,
#   'MBO_ORDER_ID_RT': '40854017',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 30, 58, 4000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58602DD0>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 0.699999988079071,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 30, 58, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58602BF0>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 0.699999988079071,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 11,
#   'MBO_ORDER_ID_RT': '41700097',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 31, 0, 10000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58602F20>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 0.75,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 6000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 31, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58603D30>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 0.75,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 31, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58603340>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 0.699999988079071,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 31, 1, 15000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58603250>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 31, 1, 15000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58603F40>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.0,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 0,
#   'MBL_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 31, 1, 15000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586030D0>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 0.8199999928474426,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 14000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 31, 1, 15000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58602F50>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 12,
#   'MBO_ORDER_ID_RT': '42165761',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 31, 1, 14000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58602B60>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 0.7099999785423279,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 10000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'DEL',
#   'MBO_SEQNUM_RT': 13,
#   'MBO_ORDER_ID_RT': '31445761',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 31, 1, 15000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58451540>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 10000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 14,
#   'MBO_ORDER_ID_RT': '42168833',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 31, 1, 15000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5834C430>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 14000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 31, 1, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586880A0>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 0.7099999785423279,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 31, 1, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688160>),
#   'MBO_BID_POSITION_RT': 6,
#   'MBO_BID_RT': 0.699999988079071,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 0.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 0,
#   'MBL_ASK_SIZE_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 39, 51, 581000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688220>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 1.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 1,
#   'MBL_ASK_SIZE_RT': 10000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 39, 51, 581000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586882E0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 1,
#   'MBO_ASK_RT': 1.0,
#   'MBO_ASK_BROKER_RT': ' 298',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 39, 51, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586883A0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_ASK_POSITION_RT': 2,
#   'MBO_ASK_RT': 0.0,
#   'MBO_ASK_BROKER_RT': '',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 39, 51, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688460>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 15,
#   'MBO_ORDER_ID_RT': '223932673',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 39, 51, 581000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688520>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 0.8999999761581421,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'DEL',
#   'MBO_SEQNUM_RT': 16,
#   'MBO_ORDER_ID_RT': '223932673',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 39, 51, 581000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586885E0>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 0.8999999761581421,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'DEL',
#   'MBO_SEQNUM_RT': 17,
#   'MBO_ASK_POSITION_RT': 1,
#   'MBO_ASK_RT': 0.8999999761581421,
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ORDER_ID_RT': '9121025',
#   'MBO_ASK_SIZE_RT': 2000,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 39, 51, 581000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586886A0>),
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 18,
#   'MBO_ORDER_ID_RT': '233202689',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 10, 779000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688760>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 0.8799999952316284,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 10, 779000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688820>),
#   'MBL_BID_POSITION_RT': 1,
#   'MBL_BID_RT': 0.8799999952316284,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 2,
#   'MBL_BID_SIZE_RT': 32000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 10, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586888E0>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 0.8799999952316284,
#   'MBO_BID_BROKER_RT': '8462',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 10, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586889A0>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_BROKER_RT': '7368',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 10, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688A60>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 0.8100000023841858,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 10, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688B20>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 0.75,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 10, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688BE0>),
#   'MBO_BID_POSITION_RT': 6,
#   'MBO_BID_RT': 0.7099999785423279,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 10, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688CA0>),
#   'MBO_BID_POSITION_RT': 7,
#   'MBO_BID_RT': 0.699999988079071,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 19,
#   'MBO_ORDER_ID_RT': '233877761',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 12, 226000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688D60>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 1.0,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'DEL',
#   'MBO_SEQNUM_RT': 20,
#   'MBO_ORDER_ID_RT': '233877761',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 12, 226000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688E20>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 1.0,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'MOD',
#   'MBO_SEQNUM_RT': 21,
#   'MBO_ASK_POSITION_RT': 1,
#   'MBO_ASK_RT': 1.0,
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ORDER_ID_RT': '2868225',
#   'MBO_ASK_SIZE_RT': 8000,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 12, 226000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688EE0>),
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 1.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 1,
#   'MBL_ASK_SIZE_RT': 8000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 12, 226000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58688FA0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'DEL',
#   'MBO_SEQNUM_RT': 22,
#   'MBO_ORDER_ID_RT': '233202689',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 17, 142000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689060>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 0.8799999952316284,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 23,
#   'MBO_ORDER_ID_RT': '235382273',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 17, 142000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689120>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 0.8899999856948853,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 17, 142000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586891E0>),
#   'MBL_BID_POSITION_RT': 1,
#   'MBL_BID_RT': 0.8799999952316284,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 17, 142000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586892A0>),
#   'MBL_BID_POSITION_RT': 1,
#   'MBL_BID_RT': 0.8899999856948853,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 17, 142000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689360>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 0.8799999952316284,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 17, 142000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689420>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.8199999928474426,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 14000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 17, 142000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586894E0>),
#   'MBL_BID_POSITION_RT': 4,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 17, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586895A0>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 0.8899999856948853,
#   'MBO_BID_BROKER_RT': '8462',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 17, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689660>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 0.8799999952316284,
#   'MBO_BID_BROKER_RT': '8578',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 24,
#   'MBO_ORDER_ID_RT': '235891969',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 19, 370000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689720>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 0.800000011920929,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 19, 370000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586897E0>),
#   'MBL_BID_POSITION_RT': 5,
#   'MBL_BID_RT': 0.800000011920929,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 19, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586898A0>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 0.800000011920929,
#   'MBO_BID_BROKER_RT': '4839',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 19, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689960>),
#   'MBO_BID_POSITION_RT': 6,
#   'MBO_BID_RT': 0.75,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 19, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689A20>),
#   'MBO_BID_POSITION_RT': 7,
#   'MBO_BID_RT': 0.7099999785423279,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 19, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689AE0>),
#   'MBO_BID_POSITION_RT': 8,
#   'MBO_BID_RT': 0.699999988079071,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 2,
#   'MBL_ASK_RT': 1.0500001907348633,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 1,
#   'MBL_ASK_SIZE_RT': 10000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 30, 883000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689BA0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 25,
#   'MBO_ASK_POSITION_RT': 2,
#   'MBO_ASK_RT': 1.0500001907348633,
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ORDER_ID_RT': '239313153',
#   'MBO_ASK_SIZE_RT': 10000,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 30, 883000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689C60>),
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 2,
#   'MBO_ASK_RT': 1.0500001907348633,
#   'MBO_ASK_BROKER_RT': ' 298',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 30, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689D20>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 26,
#   'MBO_ASK_POSITION_RT': 3,
#   'MBO_ASK_RT': 1.1000003814697266,
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ORDER_ID_RT': '241364737',
#   'MBO_ASK_SIZE_RT': 10000,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 39, 184000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689DE0>),
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 3,
#   'MBO_ASK_RT': 1.1000003814697266,
#   'MBO_ASK_BROKER_RT': ' 298',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 40, 39, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689EA0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 27,
#   'MBO_ASK_POSITION_RT': 2,
#   'MBO_ASK_RT': 1.0,
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ORDER_ID_RT': '266274561',
#   'MBO_ASK_SIZE_RT': 8000,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 8, 113000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A58689F60>),
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 1.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 2,
#   'MBL_ASK_SIZE_RT': 16000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 8, 113000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A020>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 2,
#   'MBO_ASK_RT': 1.0,
#   'MBO_ASK_BROKER_RT': '8462',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 8, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A0E0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 3,
#   'MBO_ASK_RT': 1.0500001907348633,
#   'MBO_ASK_BROKER_RT': ' 298',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 8, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A1A0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 4,
#   'MBO_ASK_RT': 1.1000003814697266,
#   'MBO_ASK_BROKER_RT': ' 298',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 8, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A260>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 36, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A320>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 36, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A3E0>),
#   'MBL_BID_POSITION_RT': 4,
#   'MBL_BID_RT': 0.800000011920929,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 36, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A4A0>),
#   'MBL_BID_POSITION_RT': 5,
#   'MBL_BID_RT': 0.0,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 0,
#   'MBL_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 36, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A560>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.8199999928474426,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 36, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A620>),
#   'MBL_BID_POSITION_RT': 4,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 36, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A6E0>),
#   'MBL_BID_POSITION_RT': 5,
#   'MBL_BID_RT': 0.800000011920929,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'DEL',
#   'MBO_SEQNUM_RT': 28,
#   'MBO_ORDER_ID_RT': '42168833',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 36, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A7A0>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 14000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 29,
#   'MBO_ORDER_ID_RT': '279457281',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 42, 36, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A860>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 30,
#   'MBO_ASK_POSITION_RT': 3,
#   'MBO_ASK_RT': 1.0,
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ORDER_ID_RT': '411532801',
#   'MBO_ASK_SIZE_RT': 42000,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 49, 46, 791000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A920>),
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 1.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 3,
#   'MBL_ASK_SIZE_RT': 58000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 49, 46, 791000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868A9E0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 3,
#   'MBO_ASK_RT': 1.0,
#   'MBO_ASK_BROKER_RT': '5227',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 49, 46, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868AAA0>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 4,
#   'MBO_ASK_RT': 1.0500001907348633,
#   'MBO_ASK_BROKER_RT': ' 298',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 49, 46, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868AB60>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_ASK_POSITION_RT': 5,
#   'MBO_ASK_RT': 1.1000003814697266,
#   'MBO_ASK_BROKER_RT': ' 298',
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ASK_SIZE_RT': 0,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 49, 46, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868AC20>),
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'DEL',
#   'MBO_SEQNUM_RT': 31,
#   'MBO_ORDER_ID_RT': '279457281',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 50, 35, 247000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868ACE0>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 32,
#   'MBO_ORDER_ID_RT': '428000257',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 50, 35, 247000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868ADA0>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 26000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 50, 35, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868AE60>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 50, 35, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868AF20>),
#   'MBL_BID_POSITION_RT': 4,
#   'MBL_BID_RT': 0.800000011920929,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 50, 35, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868AFE0>),
#   'MBL_BID_POSITION_RT': 5,
#   'MBL_BID_RT': 0.0,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 0,
#   'MBL_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 50, 35, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868B0A0>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.8199999928474426,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 26000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 50, 35, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868B160>),
#   'MBL_BID_POSITION_RT': 4,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 50, 35, 248000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868B220>),
#   'MBL_BID_POSITION_RT': 5,
#   'MBL_BID_RT': 0.800000011920929,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 33,
#   'MBO_ASK_POSITION_RT': 1,
#   'MBO_ASK_RT': 0.9100000262260437,
#   'MBO_ASK_COND_CODE_RT': '',
#   'MBO_ORDER_ID_RT': '577304321',
#   'MBO_ASK_SIZE_RT': 500000,
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 58, 40, 817000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868B2E0>),
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'MOD',
#   'MBO_SEQNUM_RT': 34,
#   'MBO_ORDER_ID_RT': '428000257',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 1, 58, 40, 818000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868B3A0>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 6000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_ASK_POSITION_RT': 1,
#   'MBL_ASK_RT': 0.9100000262260437,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 1,
#   'MBL_ASK_SIZE_RT': 500000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 58, 40, 817000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868B460>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_ASK_POSITION_RT': 2,
#   'MBL_ASK_RT': 1.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 3,
#   'MBL_ASK_SIZE_RT': 58000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 58, 40, 817000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868B520>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 3,
#   'MBL_ASK_RT': 1.0500001907348633,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 1,
#   'MBL_ASK_SIZE_RT': 10000,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 58, 40, 817000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868B5E0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'ASK',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_ASK_POSITION_RT': 3,
#   'MBL_ASK_RT': 0.0,
#   'MBL_ASK_COND_CODE_RT': '',
#   'MBL_ASK_NUM_ORDERS_RT': 0,
#   'MBL_ASK_SIZE_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 58, 40, 817000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868B6A0>),
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 1, 58, 40, 818000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A5868B760>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.8199999928474426,
#   'MBL_BID_COND_CODE_RT': '',
# ...
#   'MBL_BID_RT': 0.8199999928474426,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 18, 120000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A17E0>),
#   'MBL_BID_POSITION_RT': 4,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 18, 120000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A18A0>),
#   'MBL_BID_POSITION_RT': 5,
#   'MBL_BID_RT': 0.800000011920929,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 2,
#   'MBL_BID_SIZE_RT': 22000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 18, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A1960>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 0.8600000143051147,
#   'MBO_BID_BROKER_RT': '5339',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 18, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A1A20>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 0.8500000238418579,
#   'MBO_BID_BROKER_RT': ' 298',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 18, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A1AE0>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_BROKER_RT': '3646',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 18, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A1BA0>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 0.8100000023841858,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 18, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A1C60>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 0.800000011920929,
#   'MBO_BID_BROKER_RT': '4839',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 18, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A1D20>),
#   'MBO_BID_POSITION_RT': 6,
#   'MBO_BID_RT': 0.800000011920929,
#   'MBO_BID_BROKER_RT': ' 298',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 18, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A1DE0>),
#   'MBO_BID_POSITION_RT': 7,
#   'MBO_BID_RT': 0.75,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 18, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A1EA0>),
#   'MBO_BID_POSITION_RT': 8,
#   'MBO_BID_RT': 0.699999988079071,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 57,
#   'MBO_ORDER_ID_RT': '1696952577',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 18, 120000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A1F60>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 0.8600000143051147,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'MOD',
#   'MBO_SEQNUM_RT': 58,
#   'MBO_ORDER_ID_RT': '1683135233',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 30, 747000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2020>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 22000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 30, 747000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A20E0>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.8199999928474426,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 22000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'DEL',
#   'MBO_SEQNUM_RT': 59,
#   'MBO_ORDER_ID_RT': '1683135233',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 41, 247000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A21A0>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 22000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'ADD',
#   'MBO_SEQNUM_RT': 60,
#   'MBO_ORDER_ID_RT': '1700436481',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 41, 247000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2260>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 41, 247000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2320>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 41, 247000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A23E0>),
#   'MBL_BID_POSITION_RT': 4,
#   'MBL_BID_RT': 0.800000011920929,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 2,
#   'MBL_BID_SIZE_RT': 22000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 41, 247000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A24A0>),
#   'MBL_BID_POSITION_RT': 5,
#   'MBL_BID_RT': 0.0,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 0,
#   'MBL_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 41, 247000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2560>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.8199999928474426,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 41, 247000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2620>),
#   'MBL_BID_POSITION_RT': 4,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 30, 41, 247000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A26E0>),
#   'MBL_BID_POSITION_RT': 5,
#   'MBL_BID_RT': 0.800000011920929,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 2,
#   'MBL_BID_SIZE_RT': 22000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, 50000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A27A0>),
#   'MBL_BID_POSITION_RT': 1,
#   'MBL_BID_RT': 0.8500000238418579,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 10000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, 50000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2860>),
#   'MBL_BID_POSITION_RT': 2,
#   'MBL_BID_RT': 0.8199999928474426,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 30000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, 50000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2920>),
#   'MBL_BID_POSITION_RT': 3,
#   'MBL_BID_RT': 0.8100000023841858,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 1,
#   'MBL_BID_SIZE_RT': 20000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MD_MULTI_TICK_UPD_RT': 1,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, 50000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A29E0>),
#   'MBL_BID_POSITION_RT': 4,
#   'MBL_BID_RT': 0.800000011920929,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 2,
#   'MBL_BID_SIZE_RT': 22000,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_LEVEL',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MD_MULTI_TICK_UPD_RT': 0,
#   'MBL_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, 50000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2AA0>),
#   'MBL_BID_POSITION_RT': 5,
#   'MBL_BID_RT': 0.0,
#   'MBL_BID_COND_CODE_RT': '',
#   'MBL_BID_NUM_ORDERS_RT': 0,
#   'MBL_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'MBL'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 53714,
#   'MD_TABLE_CMD_RT': 'DEL',
#   'MBO_SEQNUM_RT': 61,
#   'MBO_ORDER_ID_RT': '1696952577',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, 50000, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2B60>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 0.8600000143051147,
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 2000,
#   'SUBSCRIPTION_TYPE': 'MBO'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2C20>),
#   'MBO_BID_POSITION_RT': 1,
#   'MBO_BID_RT': 0.8500000238418579,
#   'MBO_BID_BROKER_RT': ' 298',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2CE0>),
#   'MBO_BID_POSITION_RT': 2,
#   'MBO_BID_RT': 0.8199999928474426,
#   'MBO_BID_BROKER_RT': '3646',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2DA0>),
#   'MBO_BID_POSITION_RT': 3,
#   'MBO_BID_RT': 0.8100000023841858,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2E60>),
#   'MBO_BID_POSITION_RT': 4,
#   'MBO_BID_RT': 0.800000011920929,
#   'MBO_BID_BROKER_RT': '4839',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2F20>),
#   'MBO_BID_POSITION_RT': 5,
#   'MBO_BID_RT': 0.800000011920929,
#   'MBO_BID_BROKER_RT': ' 298',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A2FE0>),
#   'MBO_BID_POSITION_RT': 6,
#   'MBO_BID_RT': 0.75,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A30A0>),
#   'MBO_BID_POSITION_RT': 7,
#   'MBO_BID_RT': 0.699999988079071,
#   'MBO_BID_BROKER_RT': '1836',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'},
#  {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#   'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#   'EID': 14112,
#   'MD_TABLE_CMD_RT': 'REPLACE_CLEAR',
#   'MBO_TIME_RT': datetime.datetime(2023, 6, 14, 5, 35, 15, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000013A586A3160>),
#   'MBO_BID_POSITION_RT': 8,
#   'MBO_BID_RT': 0.0,
#   'MBO_BID_BROKER_RT': '',
#   'MBO_BID_COND_CODE_RT': '',
#   'MBO_BID_SIZE_RT': 0,
#   'SUBSCRIPTION_TYPE': 'TOP'}]

# %%
msgList[-1]
# Out:
# {'MKTDEPTH_EVENT_TYPE': 'MARKET_BY_ORDER',
#  'MKTDEPTH_EVENT_SUBTYPE': 'BID',
#  'EID': 14112,
#  'MD_TABLE_CMD_RT': 'REPLACE',
#  'MBO_TIME_RT': datetime.datetime(2023, 6, 15, 1, 36, 50, tzinfo=<blpapi.datetime.FixedOffset object at 0x0000024DB94777F0>),
#  'MBO_BID_POSITION_RT': 2,
#  'MBO_BID_RT': 0.800000011920929,
#  'MBO_BID_BROKER_RT': ' 298',
#  'MBO_BID_COND_CODE_RT': '',
#  'MBO_BID_SIZE_RT': 0,
#  'SUBSCRIPTION_TYPE': 'TOP'}

# %%
from blp import blp
from datetime import timedelta
bquery = blp.BlpQuery().start()
df = bquery.bdit(security='3738 HK Equity', event_types = ['TRADE'], start_datetime='2023-06-16T01:00:00', end_datetime = '2023-06-16T09:00:00', options=[('includeConditionCodes',True), ('includeNonPlottableEvents', True)])
df['time']+=timedelta(hours=8)

# %%
import pickle
with open('3738_HK_trades_0616.pickle','wb') as f:
    pickle.dump(df, f)
