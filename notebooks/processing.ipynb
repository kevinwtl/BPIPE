# %%
from msg_parsing import OrderBook
import pandas as pd

# %%
x = OrderBook(ticker='970 HK Equity',date='20230621')
x.run()
# Out:
# 100%|██████████| 42/42 [00:00<00:00, 105.02it/s]

# %%
x.journal_df
# Out:
#                      Timestamp BrokerID  Price Side       Size  \
# 0   2023-06-21 09:30:10.081000     8578   0.94  ASK    30000.0
# 1   2023-06-21 09:30:22.539000     3646   0.83  BID     2000.0
# 2   2023-06-21 09:30:52.038000     3646   0.83  BID     2000.0
# 3   2023-06-21 09:31:38.017000     3646   0.71  BID    10000.0
# 4   2023-06-21 09:31:38.018000     3646   0.73  BID     4000.0
# 5   2023-06-21 09:31:43.039000     3646   0.73  BID     4000.0
# 6   2023-06-21 10:07:44.267000     2280   0.92  ASK    50000.0
# 7   2023-06-21 13:00:27.039000     3646   0.73  BID     6000.0
# 8   2023-06-21 14:15:09.144000      197   0.91  ASK  2600000.0
# 9   2023-06-21 14:15:09.145000     3646   0.73  BID     6000.0
# 10  2023-06-21 14:15:42.426000      197   0.91  ASK  2600000.0
# 11  2023-06-21 14:15:42.472000     5344   0.91  ASK    10000.0
# 12  2023-06-21 14:16:16.365000     3646   0.56  BID    10000.0
# 13  2023-06-21 14:16:16.365000     1836   0.56  BID    20000.0
# ...

# %%
from charting import gross_buy_sell
gross_buy_sell(x.journal_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# t:\Intern Folder\External Research\2023 Interns\BPIPE\notebooks\processing.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/t%3A/Intern%20Folder/External%20Research/2023%20Interns/BPIPE/notebooks/processing.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> from charting import gross_buy_sell
# ----> <a href='vscode-notebook-cell:/t%3A/Intern%20Folder/External%20Research/2023%20Interns/BPIPE/notebooks/processing.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> gross_buy_sell(x.journal_df)
#
# File t:\Intern Folder\External Research\2023 Interns\BPIPE\charting.py:10, in gross_buy_sell(data)
#       8 group_broker = data.groupby(by=["Broker Name", 'Side'])['Size'].sum()/1000
#       9 group_broker = group_broker.unstack(level=-1)
# ...

# %%
x.journal_df.to_csv('res/3738 HK Trade Journal.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# t:\Intern Folder\External Research\2023 Interns\BPIPE\notebooks\processing.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/t%3A/Intern%20Folder/External%20Research/2023%20Interns/BPIPE/notebooks/processing.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> x.journal_df.to_csv('res/3738 HK Trade Journal.csv',index=False)
#
# File c:\Users\kevinwong\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
# ...
